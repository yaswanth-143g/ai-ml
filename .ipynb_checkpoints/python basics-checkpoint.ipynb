# %% [markdown]
# ### python basics

# %% [markdown]
# 1. Variables and data types

# %%
name="yaswanth"
age=20
height=6.0
student=True

# %%
print(name)
# Out:
# yaswanth

# %%
print(age,height,student)
# Out:
# 20 6.0 True

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
print(type(height))
print(type(student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(float(age))
# Out:
# 20.0

# %%
print(int(height))
# Out:
# 6

# %% [markdown]
# Input/output

# %%
print("hello world from python")
# Out:
# hello world from python

# %%
name=input("Enter your name : ")
age=input("Enter your age : ")
height=input("Enter your height : ")
print(f"hi my name is {name}.I am {age} years old. My height is {height}")
# Out:
# Enter your name :  yaswanth
# Enter your age :  20
# Enter your height :  6.0
# hi my name is yaswanth.I am 20 years old. My height is 6.0

# %%
a= int(input("enter the value of a: "))
print(a**3)
# Out:
# enter the value of a:  30
# 27000

# %%
import math

# %%
a= int(input("enter the value of a: "))
print(f"percentage{a:.1F}%")
# Out:
# enter the value of a:  54
# percentage54.0%

# %%
print("percentage",a,"%")
# Out:
# percentage 54 %

# %% [markdown]
# operations

# %%
a,b = 20,10
c=2
print(a+b)#add
print(a-b)#sub
print(a*b)#mul
print(a/b)#div
print(a//b)#floor div
print(a**2)#power
print(a%b)#remainder
# Out:
# 30
# 10
# 200
# 2.0
# 2
# 400
# 0

# %%
a=20
b=49
c=38
d=a*b*(c-5)
print(d)
# Out:
# 32340

# %% [markdown]
# comparision operators

# %%
print(10>5)
print(10==5)
# Out:
# True
# False

# %% [markdown]
# logical operation

# %%
x,y= True,False
print(x and y)
print(x or y)
print(not y)
# Out:
# False
# True
# True

# %% [markdown]
# ### list
# '''
# it is mutable.
# it stores different data types.
# it defines in "[]" (square bracket)
# '''

# %%
num=[10,20,30,40,50]
print(num)
print(num[0])
print(num[0:3])
print(num[3:])
print(num[:4])
# Out:
# [10, 20, 30, 40, 50]
# 10
# [10, 20, 30]
# [40, 50]
# [10, 20, 30, 40]

# %% [markdown]
# modify,append,remove lists

# %%
fruits=["apple","banana","mango","grapes"]
print(fruits[1])
# Out:
# banana

# %%
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'grapes', 'orange']

# %%
fruits.remove("grapes")
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
print(len(fruits))
# Out:
# 4

# %%
nums=[2,10,5,4,1,3]
print(nums.sort())
# Out:
# None

# %%
print(nums)
print(nums[:-1])
print(nums[::-1])
# Out:
# [1, 2, 3, 4, 5, 10]
# [1, 2, 3, 4, 5]
# [10, 5, 4, 3, 2, 1]

# %% [markdown]
# ### loops

# %% [markdown]
# ##### for loop

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
marks=[70,80,90,50,40]
marks.sort()
for i in marks:
    print(i)
# Out:
# 40
# 50
# 70
# 80
# 90

# %% [markdown]
# #### while loop

# %%
count=1
while count<=5:
    print(count)
    count+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### condition

# %%
age=15
if age>=18:
    print("adult")
else:
    print("minor")
# Out:
# minor

# %%
a=int(input("enter your marks : "))
if a>=90:
    print("A grade")
elif a>=80 and a<90:
    print("B grade")
elif a>=40 and a<=70:
    print("c Grade")
else:
    print("fail")
# Out:
# enter your marks :  89
# B grade

# %% [markdown]
# ### function

# %%
#define a function
def greet():
    print("hello")

#call the function
greet()
# Out:
# hello

# %%
def add(a,b):
    return a*b

add(2,3)
# Out:
# 6

# %%
def state(nums):
    return min(nums),max(nums),sum(nums)/len(nums)

nums=[20,30,4,49]
a=nums
print(state(a))
# Out:
# (4, 49, 25.75)
