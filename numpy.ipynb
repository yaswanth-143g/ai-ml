# %%
import numpy as np

# %%
big_list = list(range(100000))
big_array= np.arange(100000)

# %%
# %timeit [x**2 for x in big_list]
# Out:
# 11.1 ms ± 142 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit big_array ** 2
# Out:
# 98.6 μs ± 1.9 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
a=np.array([1,2,3,4,5,6])
print(a)
# Out:
# [1 2 3 4 5 6]

# %%
b=np.array([[1,2,3,4],[6,7,8,9]])
print(b)
# Out:
# [[1 2 3 4]
#  [6 7 8 9]]

# %%
a=np.array([0,0,0,0])
print(a)
# Out:
# [0 0 0 0]

# %%
zero =np.zeros((2,3))
print(zero)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.ones((2,3)))
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
print(np.full((2,3),7))
# Out:
# [[7 7 7]
#  [7 7 7]]

# %%
print(np.arange(0,10,2))
# Out:
# [0 2 4 6 8]

# %%
print(np.eye(3)) #identity matrix
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
rng = np.random.default_rng(42)
print(rng.random((2,3)))
# Out:
# [[0.77395605 0.43887844 0.85859792]
#  [0.69736803 0.09417735 0.97562235]]

# %%
print(rng.integers(1,10,size=(3,3))) #uniform
# Out:
# [[7 7 7]
#  [8 5 2]
#  [8 5 5]]
